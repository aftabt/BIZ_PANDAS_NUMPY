# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Q1. Read superstore data

# %%
df = pd.read_excel(r"C:\Users\Aftab\Desktop\Assignment\Assignment 2\Superstore.xls")

# %%
df
# Out:
#           no       order _id Order Date  Ship Date       Ship Mode  \
# 0        NaN             NaN 2016-11-08 2016-11-11    Second Class
# 1        2.0  CA-2016-152156 2016-11-08 2016-11-11    Second Class
# 2        3.0  CA-2016-138688 2016-06-12 2016-06-16    Second Class
# 3        4.0  US-2015-108966 2015-10-11 2015-10-18  Standard Class
# 4        5.0  US-2015-108966 2015-10-11 2015-10-18  Standard Class
# ...      ...             ...        ...        ...             ...
# 9989  9990.0  CA-2014-110422 2014-01-21 2014-01-23    Second Class
# 9990  9991.0  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 9991  9992.0  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 9992  9993.0  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 9993  9994.0  CA-2017-119914 2017-05-04 2017-05-09    Second Class
#
#      Customer ID     Customer Name    Segment        Country             City  \
# 0       CG-12520       Claire Gute   Consumer  United States        Henderson
# ...

# %% [markdown]
# ### Q2. find the index of the data

# %%
df.index
# Out:
# RangeIndex(start=0, stop=9994, step=1)

# %%
df.index.values
# Out:
# array([   0,    1,    2, ..., 9991, 9992, 9993], dtype=int64)

# %%
df.index.shape
# Out:
# (9994,)

# %% [markdown]
# ### Q3. find the columns of the data

# %%
df.columns
# Out:
# Index(['no', 'order _id', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'Country', 'City', 'State',
#        'Postal Code', 'Region', 'Product ID', 'Category', 'Sub-Category',
#        'Product Name', 'Sales', 'Quantity', 'Discount', 'Profit'],
#       dtype='object')

# %%
df.columns.values
# Out:
# array(['no', 'order _id', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'Country', 'City',
#        'State', 'Postal Code', 'Region', 'Product ID', 'Category',
#        'Sub-Category', 'Product Name', 'Sales', 'Quantity', 'Discount',
#        'Profit'], dtype=object)

# %%
df.columns.shape
# Out:
# (21,)

# %% [markdown]
# ### Q4. if columns name is having space then remove the space and rename the column. find the various ways to rename the column

# %%
df.columns = df.columns.str.replace(" ","")

# %%
df
# Out:
#           no        order_id  OrderDate   ShipDate        ShipMode CustomerID  \
# 0        NaN             NaN 2016-11-08 2016-11-11    Second Class   CG-12520
# 1        2.0  CA-2016-152156 2016-11-08 2016-11-11    Second Class   CG-12520
# 2        3.0  CA-2016-138688 2016-06-12 2016-06-16    Second Class   DV-13045
# 3        4.0  US-2015-108966 2015-10-11 2015-10-18  Standard Class   SO-20335
# 4        5.0  US-2015-108966 2015-10-11 2015-10-18  Standard Class   SO-20335
# ...      ...             ...        ...        ...             ...        ...
# 9989  9990.0  CA-2014-110422 2014-01-21 2014-01-23    Second Class   TB-21400
# 9990  9991.0  CA-2017-121258 2017-02-26 2017-03-03  Standard Class   DB-13060
# 9991  9992.0  CA-2017-121258 2017-02-26 2017-03-03  Standard Class   DB-13060
# 9992  9993.0  CA-2017-121258 2017-02-26 2017-03-03  Standard Class   DB-13060
# 9993  9994.0  CA-2017-119914 2017-05-04 2017-05-09    Second Class   CC-12220
#
# ...

# %% [markdown]
# ### Q5. display first 40 records

# %%
df.head(40)
# Out:
#       no        order_id  OrderDate   ShipDate        ShipMode CustomerID  \
# 0    NaN             NaN 2016-11-08 2016-11-11    Second Class   CG-12520
# 1    2.0  CA-2016-152156 2016-11-08 2016-11-11    Second Class   CG-12520
# 2    3.0  CA-2016-138688 2016-06-12 2016-06-16    Second Class   DV-13045
# 3    4.0  US-2015-108966 2015-10-11 2015-10-18  Standard Class   SO-20335
# 4    5.0  US-2015-108966 2015-10-11 2015-10-18  Standard Class   SO-20335
# 5    6.0  CA-2014-115812 2014-06-09 2014-06-14  Standard Class   BH-11710
# 6    7.0  CA-2014-115812 2014-06-09 2014-06-14  Standard Class   BH-11710
# 7    8.0  CA-2014-115812 2014-06-09 2014-06-14  Standard Class   BH-11710
# 8    9.0  CA-2014-115812 2014-06-09 2014-06-14  Standard Class   BH-11710
# 9   10.0  CA-2014-115812 2014-06-09 2014-06-14  Standard Class   BH-11710
# 10  11.0  CA-2014-115812 2014-06-09 2014-06-14  Standard Class   BH-11710
# 11  12.0  CA-2014-115812 2014-06-09 2014-06-14  Standard Class   BH-11710
# ...

# %% [markdown]
# ### Q6. display last 15 records from the data

# %%
df.tail(15)
# Out:
#           no        order_id  OrderDate   ShipDate        ShipMode CustomerID  \
# 9979  9980.0  US-2016-103674 2016-12-06 2016-12-10  Standard Class   AP-10720
# 9980  9981.0  US-2015-151435 2015-09-06 2015-09-09    Second Class   SW-20455
# 9981  9982.0  CA-2017-163566 2017-08-03 2017-08-06     First Class   TB-21055
# 9982  9983.0  US-2016-157728 2016-09-22 2016-09-28  Standard Class   RC-19960
# 9983  9984.0  US-2016-157728 2016-09-22 2016-09-28  Standard Class   RC-19960
# 9984  9985.0  CA-2015-100251 2015-05-17 2015-05-23  Standard Class   DV-13465
# 9985  9986.0  CA-2015-100251 2015-05-17 2015-05-23  Standard Class   DV-13465
# 9986  9987.0  CA-2016-125794 2016-09-29 2016-10-03  Standard Class   ML-17410
# 9987  9988.0  CA-2017-163629 2017-11-17 2017-11-21  Standard Class   RA-19885
# 9988  9989.0  CA-2017-163629 2017-11-17 2017-11-21  Standard Class   RA-19885
# 9989  9990.0  CA-2014-110422 2014-01-21 2014-01-23    Second Class   TB-21400
# ...

# %% [markdown]
# ### Q7. change the setting to display minimum 30 rows for given data

# %%
pd.options.display.min_rows = 30

# %%
df
# Out:
#           no        order_id  OrderDate   ShipDate        ShipMode CustomerID  \
# 0        NaN             NaN 2016-11-08 2016-11-11    Second Class   CG-12520
# 1        2.0  CA-2016-152156 2016-11-08 2016-11-11    Second Class   CG-12520
# 2        3.0  CA-2016-138688 2016-06-12 2016-06-16    Second Class   DV-13045
# 3        4.0  US-2015-108966 2015-10-11 2015-10-18  Standard Class   SO-20335
# 4        5.0  US-2015-108966 2015-10-11 2015-10-18  Standard Class   SO-20335
# 5        6.0  CA-2014-115812 2014-06-09 2014-06-14  Standard Class   BH-11710
# 6        7.0  CA-2014-115812 2014-06-09 2014-06-14  Standard Class   BH-11710
# 7        8.0  CA-2014-115812 2014-06-09 2014-06-14  Standard Class   BH-11710
# 8        9.0  CA-2014-115812 2014-06-09 2014-06-14  Standard Class   BH-11710
# 9       10.0  CA-2014-115812 2014-06-09 2014-06-14  Standard Class   BH-11710
# 10      11.0  CA-2014-115812 2014-06-09 2014-06-14  Standard Class   BH-11710
# ...

# %% [markdown]
# ### Q8. change the display setting to minimum row as 3

# %%
pd.options.display.min_rows = 3

# %%
df
# Out:
#           no        order_id  OrderDate   ShipDate      ShipMode CustomerID  \
# 0        NaN             NaN 2016-11-08 2016-11-11  Second Class   CG-12520
# ...      ...             ...        ...        ...           ...        ...
# 9993  9994.0  CA-2017-119914 2017-05-04 2017-05-09  Second Class   CC-12220
#
#       CustomerName   Segment        Country         City  ... PostalCode  \
# 0      Claire Gute  Consumer  United States    Henderson  ...      42420
# ...            ...       ...            ...          ...  ...        ...
# 9993  Chris Cortes  Consumer  United States  Westminster  ...      92683
#
#       Region        ProductID         Category Sub-Category  \
# 0      South  FUR-BO-10001798        Furniture    Bookcases
# ...      ...              ...              ...          ...
# 9993    West  OFF-AP-10002684  Office Supplies   Appliances
#
#                                             ProductName   Sales  Quantity  \
# ...

# %% [markdown]
# ### Q9 take a slice from the dataframe based on the columns city, state, region, profit columns

# %%
df.columns
# Out:
# Index(['no', 'order_id', 'OrderDate', 'ShipDate', 'ShipMode', 'CustomerID',
#        'CustomerName', 'Segment', 'Country', 'City', 'State', 'PostalCode',
#        'Region', 'ProductID', 'Category', 'Sub-Category', 'ProductName',
#        'Sales', 'Quantity', 'Discount', 'Profit'],
#       dtype='object')

# %%
df.loc[1:10,["City","State","Region","Profit"]]
# Out:
#                City       State Region    Profit
# 1         Henderson    Kentucky  South  219.5820
# 2       Los Angeles  California   West    6.8714
# 3   Fort Lauderdale     Florida  South -383.0310
# 4   Fort Lauderdale     Florida  South    2.5164
# 5       Los Angeles  California   West   14.1694
# 6       Los Angeles  California   West    1.9656
# 7       Los Angeles  California   West   90.7152
# 8       Los Angeles  California   West    5.7825
# 9       Los Angeles  California   West   34.4700
# 10      Los Angeles  California   West   85.3092

# %% [markdown]
# ### Q10. Take a slice based on data available at 1000 to 1500 position and columns from 4 to 8

# %%
pd.options.display.min_rows = 10

# %%
df.iloc[1000:1500, 4:5]
# Out:
#             ShipMode
# 1000  Standard Class
# 1001        Same Day
# 1002        Same Day
# 1003        Same Day
# 1004  Standard Class
# ...              ...
# 1495  Standard Class
# 1496  Standard Class
# 1497  Standard Class
# 1498     First Class
# 1499  Standard Class
#
# [500 rows x 1 columns]

# %% [markdown]
# ### Q11. Rename the index starts from 1900 to end of the data

# %%
df.index = range(1900, 1900 + len(df))

# %%
df
# Out:
#            no        order_id  OrderDate   ShipDate        ShipMode  \
# 1900      NaN             NaN 2016-11-08 2016-11-11    Second Class
# 1901      2.0  CA-2016-152156 2016-11-08 2016-11-11    Second Class
# 1902      3.0  CA-2016-138688 2016-06-12 2016-06-16    Second Class
# 1903      4.0  US-2015-108966 2015-10-11 2015-10-18  Standard Class
# 1904      5.0  US-2015-108966 2015-10-11 2015-10-18  Standard Class
# ...       ...             ...        ...        ...             ...
# 11889  9990.0  CA-2014-110422 2014-01-21 2014-01-23    Second Class
# 11890  9991.0  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 11891  9992.0  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 11892  9993.0  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 11893  9994.0  CA-2017-119914 2017-05-04 2017-05-09    Second Class
#
#       CustomerID      CustomerName    Segment        Country             City  \
# ...

# %% [markdown]
# ### Q12. Take a slice from data based on index having name as 1920 , 1940, 1945, 1980, and columns as profit, state, category, sub-category, region

# %%
df.loc[[1920,1940,1945,1980],["Profit","State","Category","Sub-Category"]]
# Out:
#        Profit       State         Category Sub-Category
# 1920   7.3840  California  Office Supplies      Binders
# 1940  41.7564       Texas       Technology       Phones
# 1945   8.2062   Minnesota  Office Supplies      Binders
# 1980   8.0352     Alabama  Office Supplies      Binders

# %% [markdown]
# ### Q13. Check the data type of columns

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 1900 to 11893
# Data columns (total 21 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   no            9993 non-null   float64
#  1   order_id      9993 non-null   object
#  2   OrderDate     9994 non-null   datetime64[ns]
#  3   ShipDate      9994 non-null   datetime64[ns]
#  4   ShipMode      9994 non-null   object
#  5   CustomerID    9994 non-null   object
#  6   CustomerName  9994 non-null   object
#  7   Segment       9994 non-null   object
#  8   Country       9994 non-null   object
#  9   City          9994 non-null   object
#  10  State         9994 non-null   object
#  11  PostalCode    9994 non-null   int64
#  12  Region        9994 non-null   object
#  13  ProductID     9994 non-null   object
#  14  Category      9994 non-null   object
#  15  Sub-Category  9994 non-null   object
#  16  ProductName   9994 non-null   object
# ...

# %%
df.dtypes
# Out:
# no                     float64
# order_id                object
# OrderDate       datetime64[ns]
# ShipDate        datetime64[ns]
# ShipMode                object
# CustomerID              object
# CustomerName            object
# Segment                 object
# Country                 object
# City                    object
# State                   object
# PostalCode               int64
# Region                  object
# ProductID               object
# Category                object
# Sub-Category            object
# ProductName             object
# Sales                  float64
# Quantity                 int64
# Discount               float64
# Profit                 float64
# dtype: object

# %% [markdown]
# ### Q14. Find out the record for the month of jun-2014

# %%
df[(df["OrderDate"] >= "2014-06-01") & (df["OrderDate"] <= "2014-06-30")]
# Out:
#            no        order_id  OrderDate   ShipDate        ShipMode  \
# 1905      6.0  CA-2014-115812 2014-06-09 2014-06-14  Standard Class
# 1906      7.0  CA-2014-115812 2014-06-09 2014-06-14  Standard Class
# 1907      8.0  CA-2014-115812 2014-06-09 2014-06-14  Standard Class
# 1908      9.0  CA-2014-115812 2014-06-09 2014-06-14  Standard Class
# 1909     10.0  CA-2014-115812 2014-06-09 2014-06-14  Standard Class
# ...       ...             ...        ...        ...             ...
# 11664  9765.0  CA-2014-123855 2014-06-18 2014-06-23  Standard Class
# 11743  9844.0  CA-2014-163867 2014-06-03 2014-06-06     First Class
# 11744  9845.0  CA-2014-163867 2014-06-03 2014-06-06     First Class
# 11745  9846.0  CA-2014-163867 2014-06-03 2014-06-06     First Class
# 11796  9897.0  CA-2014-156342 2014-06-17 2014-06-20    Second Class
#
#       CustomerID       CustomerName   Segment        Country         City  \
# 1905    BH-11710    Brosina Hoffman  Consumer  United States  Los Angeles
# ...

# %% [markdown]
# ### Q15. Calculate month wise average of profit.

# %%
df.groupby(df["OrderDate"].dt.month)["Profit"].mean()
# Out:
# OrderDate
# 1     23.974924
# 2     34.315369
# 3     41.084321
# 4     17.346462
# 5     30.491575
# 6     29.687302
# 7     19.482626
# 8     30.845522
# 9     26.650380
# 10    38.808353
# 11    24.111779
# 12    30.801983
# Name: Profit, dtype: float64

# %% [markdown]
# ### Q16. Create the new data frame for California

# %%
df[df["State"] == "California"]
# Out:
#            no        order_id  OrderDate   ShipDate        ShipMode  \
# 1902      3.0  CA-2016-138688 2016-06-12 2016-06-16    Second Class
# 1905      6.0  CA-2014-115812 2014-06-09 2014-06-14  Standard Class
# 1906      7.0  CA-2014-115812 2014-06-09 2014-06-14  Standard Class
# 1907      8.0  CA-2014-115812 2014-06-09 2014-06-14  Standard Class
# 1908      9.0  CA-2014-115812 2014-06-09 2014-06-14  Standard Class
# ...       ...             ...        ...        ...             ...
# 11886  9987.0  CA-2016-125794 2016-09-29 2016-10-03  Standard Class
# 11890  9991.0  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 11891  9992.0  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 11892  9993.0  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 11893  9994.0  CA-2017-119914 2017-05-04 2017-05-09    Second Class
#
#       CustomerID     CustomerName    Segment        Country         City  ...  \
# ...

# %% [markdown]
# ### Q17. Find sum of sales

# %%
df["Sales"].sum()
# Out:
# 2297200.8603000003

# %% [markdown]
# ### Q18. Find state wise sum of sales.

# %%
df.groupby(df['State'])["Sales"].mean()
# Out:
# State
# Alabama                  319.846557
# Arizona                  157.508933
# Arkansas                 194.635500
# California               228.729451
# Colorado                 176.418231
# Connecticut              163.223866
# Delaware                 285.948635
# District of Columbia     286.502000
# Florida                  233.612815
# Georgia                  266.825217
# Idaho                    208.689810
# Illinois                 162.939230
# Indiana                  359.431946
# Iowa                     152.658667
# Kansas                   121.429583
# Kentucky                 263.250000
# Louisiana                219.453095
# Maine                    158.816250
# Maryland                 225.766886
# Massachusetts            212.106919
# Michigan                 299.096525
# Minnesota                335.541011
# Mississippi              203.232830
# Missouri                 336.441667
# Montana                  372.623467
# Nebraska                 196.445526
# ...

# %% [markdown]
# ### Q19. Find month wise sum of sales

# %%
df.groupby(df["OrderDate"].dt.month)["Sales"].sum()
# Out:
# OrderDate
# 1      94924.8356
# 2      59751.2514
# 3     205005.4888
# 4     137762.1286
# 5     155028.8117
# 6     152718.6793
# 7     147238.0970
# 8     159044.0630
# 9     307649.9457
# 10    200322.9847
# 11    352461.0710
# 12    325293.5035
# Name: Sales, dtype: float64

# %% [markdown]
# ### Q20. Find country wise and city wise average profit

# %%
pd.concat((df.groupby(df["Country"])["Profit"].mean(),df.groupby(df["City"])["Profit"].mean()),axis = 1)
# Out:
#                   Profit      Profit
# United States  28.656896         NaN
# Aberdeen             NaN    6.630000
# Abilene              NaN   -3.758400
# Akron                NaN   -8.887410
# Albuquerque          NaN   45.292007
# ...                  ...         ...
# Woonsocket           NaN   19.669775
# Yonkers              NaN  184.517047
# York                 NaN  -20.433840
# Yucaipa              NaN   13.208000
# Yuma                 NaN -116.497725
#
# [532 rows x 2 columns]

# %%
pd.DataFrame(df.groupby(["Country","City"])["Profit"].mean())
# Out:
#                                Profit
# Country       City
# United States Aberdeen       6.630000
#               Abilene       -3.758400
#               Akron         -8.887410
#               Albuquerque   45.292007
#               Alexandria    19.913644
# ...                               ...
#               Woonsocket    19.669775
#               Yonkers      184.517047
#               York         -20.433840
#               Yucaipa       13.208000
#               Yuma        -116.497725
#
# [531 rows x 1 columns]

# %% [markdown]
# ### Q21. Calculate region wise average profit.

# %%
df.groupby(df["Region"])["Profit"].mean()
# Out:
# Region
# Central    17.092709
# East       32.135808
# South      28.857673
# West       33.849032
# Name: Profit, dtype: float64

# %% [markdown]
# ### Q22. Find the ship mode which is more profitable.

# %%
pd.DataFrame(df.groupby(df["ShipMode"])["Profit"].sum()).max()
# Out:
# Profit    164088.7875
# dtype: float64

# %% [markdown]
# ### Q23. Create a new data frame where loss is recorded

# %%
df[df["Profit"] < 0]
# Out:
#            no        order_id  OrderDate   ShipDate        ShipMode  \
# 1903      4.0  US-2015-108966 2015-10-11 2015-10-18  Standard Class
# 1914     15.0  US-2015-118983 2015-11-22 2015-11-26  Standard Class
# 1915     16.0  US-2015-118983 2015-11-22 2015-11-26  Standard Class
# 1923     24.0  US-2017-156909 2017-07-16 2017-07-18    Second Class
# 1927     28.0  US-2015-150630 2015-09-17 2015-09-21  Standard Class
# ...       ...             ...        ...        ...             ...
# 11820  9921.0  CA-2016-149272 2016-03-15 2016-03-19  Standard Class
# 11821  9922.0  CA-2014-111360 2014-11-24 2014-11-30  Standard Class
# 11831  9932.0  CA-2015-104948 2015-11-13 2015-11-17  Standard Class
# 11837  9938.0  CA-2016-164889 2016-06-03 2016-06-06    Second Class
# 11862  9963.0  CA-2015-168088 2015-03-19 2015-03-22     First Class
#
#       CustomerID      CustomerName      Segment        Country  \
# 1903    SO-20335    Sean O'Donnell     Consumer  United States
# ...

# %% [markdown]
# ### Q24. Find category wise sub category wise sales

# %%
df.groupby(["Category","Sub-Category"])["Sales"].sum()
# Out:
# Category         Sub-Category
# Furniture        Bookcases       114879.9963
#                  Chairs          328449.1030
#                  Furnishings      91705.1640
#                  Tables          206965.5320
# Office Supplies  Appliances      107532.1610
#                  Art              27118.7920
#                  Binders         203412.7330
#                  Envelopes        16476.4020
#                  Fasteners         3024.2800
#                  Labels           12486.3120
#                  Paper            78479.2060
#                  Storage         223843.6080
#                  Supplies         46673.5380
# Technology       Accessories     167380.3180
#                  Copiers         149528.0300
#                  Machines        189238.6310
#                  Phones          330007.0540
# Name: Sales, dtype: float64

# %% [markdown]
# ### Q25. Create a data frame for record where discount is 0

# %%
df[df["Discount"] == 0]
# Out:
#            no        order_id  OrderDate   ShipDate        ShipMode  \
# 1900      NaN             NaN 2016-11-08 2016-11-11    Second Class
# 1901      2.0  CA-2016-152156 2016-11-08 2016-11-11    Second Class
# 1902      3.0  CA-2016-138688 2016-06-12 2016-06-16    Second Class
# 1905      6.0  CA-2014-115812 2014-06-09 2014-06-14  Standard Class
# 1906      7.0  CA-2014-115812 2014-06-09 2014-06-14  Standard Class
# ...       ...             ...        ...        ...             ...
# 11887  9988.0  CA-2017-163629 2017-11-17 2017-11-21  Standard Class
# 11888  9989.0  CA-2017-163629 2017-11-17 2017-11-21  Standard Class
# 11890  9991.0  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 11892  9993.0  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 11893  9994.0  CA-2017-119914 2017-05-04 2017-05-09    Second Class
#
#       CustomerID     CustomerName    Segment        Country         City  ...  \
# ...

# %% [markdown]
# ### 26. Create a data frame where order date and ship date both are in JAN-2014

# %%
df[((df["OrderDate"].dt.year == 2014) & (df["OrderDate"].dt.month == 1)) & ((df["ShipDate"].dt.year == 2014) & (df["ShipDate"].dt.month == 1))]
# Out:
#            no        order_id  OrderDate   ShipDate        ShipMode  \
# 2492    593.0  CA-2014-135405 2014-01-09 2014-01-13  Standard Class
# 2493    594.0  CA-2014-135405 2014-01-09 2014-01-13  Standard Class
# 2616    717.0  CA-2014-130092 2014-01-11 2014-01-14     First Class
# 2639    740.0  CA-2014-112326 2014-01-04 2014-01-08  Standard Class
# 2640    741.0  CA-2014-112326 2014-01-04 2014-01-08  Standard Class
# ...       ...             ...        ...        ...             ...
# 11055  9156.0  CA-2014-102645 2014-01-23 2014-01-28  Standard Class
# 11528  9629.0  CA-2014-118192 2014-01-13 2014-01-18  Standard Class
# 11529  9630.0  CA-2014-118192 2014-01-13 2014-01-18  Standard Class
# 11786  9887.0  CA-2014-146997 2014-01-23 2014-01-27  Standard Class
# 11889  9990.0  CA-2014-110422 2014-01-21 2014-01-23    Second Class
#
#       CustomerID      CustomerName      Segment        Country        City  \
# ...

# %% [markdown]
# ### Q27. Find records having profit for consumer segment.

# %%
df[df["Segment"] == "Consumer"]["Profit"]
# Out:
# 1900      41.9136
# 1901     219.5820
# 1903    -383.0310
# 1904       2.5164
# 1905      14.1694
#            ...
# 11889      4.1028
# 11890     15.6332
# 11891     19.3932
# 11892     13.3200
# 11893     72.9480
# Name: Profit, Length: 5191, dtype: float64

# %%
df[df["Segment"] == "Consumer"]
# Out:
#            no        order_id  OrderDate   ShipDate        ShipMode  \
# 1900      NaN             NaN 2016-11-08 2016-11-11    Second Class
# 1901      2.0  CA-2016-152156 2016-11-08 2016-11-11    Second Class
# 1903      4.0  US-2015-108966 2015-10-11 2015-10-18  Standard Class
# 1904      5.0  US-2015-108966 2015-10-11 2015-10-18  Standard Class
# 1905      6.0  CA-2014-115812 2014-06-09 2014-06-14  Standard Class
# ...       ...             ...        ...        ...             ...
# 11889  9990.0  CA-2014-110422 2014-01-21 2014-01-23    Second Class
# 11890  9991.0  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 11891  9992.0  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 11892  9993.0  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 11893  9994.0  CA-2017-119914 2017-05-04 2017-05-09    Second Class
#
#       CustomerID      CustomerName   Segment        Country             City  \
# ...

# %% [markdown]
# ### Q28. Generate new data frame for every state (hint: dynamic variable creation)

# %%
df["State"].nunique()
# Out:
# 49

# %%
for i in df["State"].unique():
    print(i)
# Out:
# Kentucky
# California
# Florida
# North Carolina
# Washington
# Texas
# Wisconsin
# Utah
# Nebraska
# Pennsylvania
# Illinois
# Minnesota
# Michigan
# Delaware
# Indiana
# New York
# Arizona
# Virginia
# Tennessee
# Alabama
# South Carolina
# Oregon
# Colorado
# Iowa
# Ohio
# Missouri
# Oklahoma
# New Mexico
# Louisiana
# Connecticut
# New Jersey
# Massachusetts
# Georgia
# Nevada
# Rhode Island
# Mississippi
# Arkansas
# Montana
# New Hampshire
# Maryland
# District of Columbia
# Kansas
# Vermont
# Maine
# South Dakota
# Idaho
# North Dakota
# Wyoming
# West Virginia

# %%
dyn_var = {a: df[df['State'] == a] for a in df['State'].unique()}
dyn_var['California']
# Out:
#            no        order_id  OrderDate   ShipDate        ShipMode  \
# 1902      3.0  CA-2016-138688 2016-06-12 2016-06-16    Second Class
# 1905      6.0  CA-2014-115812 2014-06-09 2014-06-14  Standard Class
# 1906      7.0  CA-2014-115812 2014-06-09 2014-06-14  Standard Class
# 1907      8.0  CA-2014-115812 2014-06-09 2014-06-14  Standard Class
# 1908      9.0  CA-2014-115812 2014-06-09 2014-06-14  Standard Class
# ...       ...             ...        ...        ...             ...
# 11886  9987.0  CA-2016-125794 2016-09-29 2016-10-03  Standard Class
# 11890  9991.0  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 11891  9992.0  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 11892  9993.0  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 11893  9994.0  CA-2017-119914 2017-05-04 2017-05-09    Second Class
#
#       CustomerID     CustomerName    Segment        Country         City  ...  \
# ...

# %% [markdown]
# ### Q29. Generate the region wise, state wise average profit and sales and then extract information for east region.

# %%
df.groupby(["Region","State"])[["Profit","Sales"]].sum()
# Out:
#                                   Profit        Sales
# Region  State
# Central Illinois             -12607.8870   80166.1010
#         Indiana               18382.9363   53555.3600
#         Iowa                   1183.8119    4579.7600
#         Kansas                  836.4435    2914.3100
#         Michigan              24463.1876   76269.6140
#         Minnesota             10823.1874   29863.1500
#         Missouri               6436.2105   22205.1500
#         Nebraska               2037.0942    7464.9300
#         North Dakota            230.1497     919.9100
#         Oklahoma               4853.9560   19683.3900
#         South Dakota            394.8283    1315.5600
#         Texas                -25729.3563  170188.0458
#         Wisconsin              8401.8004   32114.6100
# East    Connecticut            3511.4918   13384.3570
#         Delaware               9977.3748   27451.0690
#         District of Columbia   1059.5893    2865.0200
# ...

# %%
(df.groupby(["Region","State"])[["Profit","Sales"]].sum()).loc['East']
# Out:
#                           Profit       Sales
# State
# Connecticut            3511.4918   13384.357
# Delaware               9977.3748   27451.069
# District of Columbia   1059.5893    2865.020
# Maine                   454.4862    1270.530
# Maryland               7031.1788   23705.523
# Massachusetts          6785.5016   28634.434
# New Hampshire          1706.5028    7292.524
# New Jersey             9772.9138   35764.312
# New York              74038.5486  310876.271
# Ohio                 -16971.3766   78258.136
# Pennsylvania         -15559.9603  116511.914
# Rhode Island           7285.6293   22627.956
# Vermont                2244.9783    8929.370
# West Virginia           185.9216    1209.824

# %% [markdown]
# ### 30. Find all record for furniture delivered in Texas

# %%
df[(df["Category"] == "Furniture") & (df["State"] == "Texas")]
# Out:
#            no        order_id  OrderDate   ShipDate        ShipMode  \
# 1936     37.0  CA-2016-117590 2016-12-08 2016-12-10     First Class
# 1938     39.0  CA-2015-117415 2015-12-27 2015-12-31  Standard Class
# 1939     40.0  CA-2015-117415 2015-12-27 2015-12-31  Standard Class
# 1976     77.0  US-2017-118038 2017-12-09 2017-12-11     First Class
# 1978     79.0  US-2014-147606 2014-11-26 2014-12-01    Second Class
# ...       ...             ...        ...        ...             ...
# 11731  9832.0  CA-2014-113257 2014-12-16 2014-12-18    Second Class
# 11734  9835.0  CA-2016-126627 2016-10-10 2016-10-12     First Class
# 11803  9904.0  CA-2014-122609 2014-11-12 2014-11-18  Standard Class
# 11819  9920.0  CA-2016-149272 2016-03-15 2016-03-19  Standard Class
# 11862  9963.0  CA-2015-168088 2015-03-19 2015-03-22     First Class
#
#       CustomerID      CustomerName      Segment        Country        City  \
# ...

# %%
df[(df["Category"] == "Furniture") & (df["State"] == "Texas")].groupby(df["State"])['Category'].size()
# Out:
#        Category
# State
# Texas       202

# %%
df
# Out:
#            no        order_id  OrderDate   ShipDate        ShipMode  \
# 1900      NaN             NaN 2016-11-08 2016-11-11    Second Class
# 1901      2.0  CA-2016-152156 2016-11-08 2016-11-11    Second Class
# 1902      3.0  CA-2016-138688 2016-06-12 2016-06-16    Second Class
# 1903      4.0  US-2015-108966 2015-10-11 2015-10-18  Standard Class
# 1904      5.0  US-2015-108966 2015-10-11 2015-10-18  Standard Class
# ...       ...             ...        ...        ...             ...
# 11889  9990.0  CA-2014-110422 2014-01-21 2014-01-23    Second Class
# 11890  9991.0  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 11891  9992.0  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 11892  9993.0  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 11893  9994.0  CA-2017-119914 2017-05-04 2017-05-09    Second Class
#
#       CustomerID      CustomerName    Segment        Country             City  \
# ...

# %%
import pandas as pd

# %%
USvid=pd.read_csv(r"C:\Users\Aftab\Downloads\datasets\USvideos.csv")

# %%
USvid.head()
# Out:
#       video_id trending_date  \
# 0  2kyS6SvSYSE      17.14.11
# 1  1ZAPwfrtAFY      17.14.11
# 2  5qpjK5DgCt4      17.14.11
# 3  puqaWrEC7tY      17.14.11
# 4  d380meD0W0M      17.14.11
#
#                                                title          channel_title  \
# 0                 WE WANT TO TALK ABOUT OUR MARRIAGE           CaseyNeistat
# 1  The Trump Presidency: Last Week Tonight with J...        LastWeekTonight
# 2  Racist Superman | Rudy Mancuso, King Bach & Le...           Rudy Mancuso
# 3                   Nickelback Lyrics: Real or Fake?  Good Mythical Morning
# 4                           I Dare You: GOING BALD!?               nigahiga
#
#    category_id              publish_time  \
# 0           22  2017-11-13T17:13:01.000Z
# 1           24  2017-11-13T07:30:00.000Z
# 2           23  2017-11-12T19:05:24.000Z
# 3           24  2017-11-13T11:00:04.000Z
# 4           24  2017-11-12T18:01:41.000Z
#
# ...

# %%
FRvid=pd.read_csv(r"C:\Users\Aftab\Downloads\datasets\FRvideos.csv")

# %%
FRvid.head()
# Out:
#       video_id trending_date  \
# 0  Ro6eob0LrCY      17.14.11
# 1  Yo84eqYwP98      17.14.11
# 2  ceqntSXE-10      17.14.11
# 3  WuTFI5qftCE      17.14.11
# 4  ee6OFs8TdEg      17.14.11
#
#                                                title        channel_title  \
# 0           Malika LePen : Femme de Gauche - Trailer  Le Raptor Dissident
# 1  LA PIRE PARTIE ft Le Rire Jaune, Pierre Croce,...              Le Labo
# 2  DESSINS ANIMÉS FRANÇAIS VS RUSSES 2 - Daniil...      Daniil le Russe
# 3                    PAPY GRENIER - METAL GEAR SOLID    Joueur Du Grenier
# 4  QUI SAUTERA LE PLUS HAUT ? (VÉLO SKATE ROLLER ...    Aurelien Fontenoy
#
#    category_id              publish_time  \
# 0           24  2017-11-13T17:32:55.000Z
# 1           24  2017-11-12T15:00:02.000Z
# 2           23  2017-11-13T17:00:38.000Z
# 3           20  2017-11-12T17:00:02.000Z
# 4           17  2017-11-13T16:30:03.000Z
#
#                                                 tags   views  likes  dislikes  \
# ...

# %%
DEvid=pd.read_csv(r"C:\Users\Aftab\Downloads\datasets\DEvideos.csv")
DEvid.head()
# Out:
#       video_id trending_date  \
# 0  LgVi6y5QIjM      17.14.11
# 1  Bayt7uQith4      17.14.11
# 2  1ZAPwfrtAFY      17.14.11
# 3  AHtypnRk7JE      17.14.11
# 4  ZJ9We4bjcg0      17.14.11
#
#                                                title            channel_title  \
# 0  Sing zu Ende! | Gesangseinlagen vom Feinsten |...                inscope21
# 1  Kinder ferngesteuert im Kiosk! Erwachsene abzo...  LUKE! Die Woche und ich
# 2  The Trump Presidency: Last Week Tonight with J...          LastWeekTonight
# 3                                Das Fermi-Paradoxon        100SekundenPhysik
# 4           18 SONGS mit Kelly MissesVlog (Sing-off)                     rezo
#
#    category_id              publish_time  \
# 0           24  2017-11-13T17:08:49.000Z
# 1           23  2017-11-12T22:30:01.000Z
# 2           24  2017-11-13T07:30:00.000Z
# 3           27  2017-11-12T15:00:01.000Z
# 4           24  2017-11-12T13:10:36.000Z
#
# ...

# %%
CAvid=pd.read_csv(r"C:\Users\Aftab\Downloads\datasets\CAvideos.csv")
CAvid.head()
# Out:
#       video_id trending_date  \
# 0  n1WpP7iowLc      17.14.11
# 1  0dBIkQ4Mz1M      17.14.11
# 2  5qpjK5DgCt4      17.14.11
# 3  d380meD0W0M      17.14.11
# 4  2Vv-BfVoq4g      17.14.11
#
#                                                title channel_title  \
# 0         Eminem - Walk On Water (Audio) ft. Beyoncé    EminemVEVO
# 1                      PLUSH - Bad Unboxing Fan Mail     iDubbbzTV
# 2  Racist Superman | Rudy Mancuso, King Bach & Le...  Rudy Mancuso
# 3                           I Dare You: GOING BALD!?      nigahiga
# 4        Ed Sheeran - Perfect (Official Music Video)    Ed Sheeran
#
#    category_id              publish_time  \
# 0           10  2017-11-10T17:00:03.000Z
# 1           23  2017-11-13T17:00:00.000Z
# 2           23  2017-11-12T19:05:24.000Z
# 3           24  2017-11-12T18:01:41.000Z
# 4           10  2017-11-09T11:04:14.000Z
#
#                                                 tags     views    likes  \
# ...

# %%
USvid.columns
# Out:
# Index(['video_id', 'trending_date', 'title', 'channel_title', 'category_id',
#        'publish_time', 'tags', 'views', 'likes', 'dislikes', 'comment_count',
#        'thumbnail_link', 'comments_disabled', 'ratings_disabled',
#        'video_error_or_removed', 'description'],
#       dtype='object')

# %%
FRvid.columns
# Out:
# Index(['video_id', 'trending_date', 'title', 'channel_title', 'category_id',
#        'publish_time', 'tags', 'views', 'likes', 'dislikes', 'comment_count',
#        'thumbnail_link', 'comments_disabled', 'ratings_disabled',
#        'video_error_or_removed', 'description'],
#       dtype='object')

# %%
DEvid.columns
# Out:
# Index(['video_id', 'trending_date', 'title', 'channel_title', 'category_id',
#        'publish_time', 'tags', 'views', 'likes', 'dislikes', 'comment_count',
#        'thumbnail_link', 'comments_disabled', 'ratings_disabled',
#        'video_error_or_removed', 'description'],
#       dtype='object')

# %%
CAvid.columns
# Out:
# Index(['video_id', 'trending_date', 'title', 'channel_title', 'category_id',
#        'publish_time', 'tags', 'views', 'likes', 'dislikes', 'comment_count',
#        'thumbnail_link', 'comments_disabled', 'ratings_disabled',
#        'video_error_or_removed', 'description'],
#       dtype='object')

# %%
vid_con=pd.concat([DEvid,CAvid,FRvid,USvid])

# %%
vid_con.isna().sum()
# Out:
# video_id                    0
# trending_date               0
# title                       0
# channel_title               0
# category_id                 0
# publish_time                0
# tags                        0
# views                       0
# likes                       0
# dislikes                    0
# comment_count               0
# thumbnail_link              0
# comments_disabled           0
# ratings_disabled            0
# video_error_or_removed      0
# description               364
# dtype: int64

# %%
##### JSON file

# %%
df_json_us=pd.read_json(r"C:\Users\Aftab\Downloads\datasets\US_category_id.json")

# %%
df_json_de=pd.read_json(r"C:\Users\Aftab\Downloads\datasets\DE_category_id.json")

# %%
df_json_ca=pd.read_json(r"C:\Users\Aftab\Downloads\datasets\CA_category_id.json")

# %%
df_json_fr=pd.read_json(r"C:\Users\Aftab\Downloads\datasets\FR_category_id.json")

# %%
df_json_con=pd.concat([df_json_de,df_json_us,df_json_ca,df_json_fr])

# %%
dt_dataframe=pd.DataFrame(df_json_con)
dt_dataframe
# Out:
#                                  kind  \
# 0   youtube#videoCategoryListResponse
# 1   youtube#videoCategoryListResponse
# 2   youtube#videoCategoryListResponse
# 3   youtube#videoCategoryListResponse
# 4   youtube#videoCategoryListResponse
# ..                                ...
# 26  youtube#videoCategoryListResponse
# 27  youtube#videoCategoryListResponse
# 28  youtube#videoCategoryListResponse
# 29  youtube#videoCategoryListResponse
# 30  youtube#videoCategoryListResponse
#
#                                                  etag  \
# 0   "ld9biNPKjAjgjV7EZ4EKeEGrhao/1v2mrzYSYG6onNLt2...
# 1   "ld9biNPKjAjgjV7EZ4EKeEGrhao/1v2mrzYSYG6onNLt2...
# 2   "ld9biNPKjAjgjV7EZ4EKeEGrhao/1v2mrzYSYG6onNLt2...
# 3   "ld9biNPKjAjgjV7EZ4EKeEGrhao/1v2mrzYSYG6onNLt2...
# 4   "ld9biNPKjAjgjV7EZ4EKeEGrhao/1v2mrzYSYG6onNLt2...
# ..                                                ...
# 26  "ld9biNPKjAjgjV7EZ4EKeEGrhao/1v2mrzYSYG6onNLt2...
# 27  "ld9biNPKjAjgjV7EZ4EKeEGrhao/1v2mrzYSYG6onNLt2...
# ...

# %%
dt_jason = pd.json_normalize(dt_dataframe["items"])
dt_jason
# Out:
#                       kind                                               etag  \
# 0    youtube#videoCategory  "ld9biNPKjAjgjV7EZ4EKeEGrhao/Xy1mB4_yLrHy_BmKm...
# 1    youtube#videoCategory  "ld9biNPKjAjgjV7EZ4EKeEGrhao/UZ1oLIIz2dxIhO45Z...
# 2    youtube#videoCategory  "ld9biNPKjAjgjV7EZ4EKeEGrhao/nqRIq97-xe5XRZTxb...
# 3    youtube#videoCategory  "ld9biNPKjAjgjV7EZ4EKeEGrhao/HwXKamM1Q20q9BN-o...
# 4    youtube#videoCategory  "ld9biNPKjAjgjV7EZ4EKeEGrhao/9GQMSRjrZdHeb1OEM...
# ..                     ...                                                ...
# 120  youtube#videoCategory  "ld9biNPKjAjgjV7EZ4EKeEGrhao/N1TrDFLRppxZgBowC...
# 121  youtube#videoCategory  "ld9biNPKjAjgjV7EZ4EKeEGrhao/7UMGi6zRySqXopr_r...
# 122  youtube#videoCategory  "ld9biNPKjAjgjV7EZ4EKeEGrhao/RScXhi324h8usyIet...
# 123  youtube#videoCategory  "ld9biNPKjAjgjV7EZ4EKeEGrhao/0n9MJVCDLpA8q7aiG...
# 124  youtube#videoCategory  "ld9biNPKjAjgjV7EZ4EKeEGrhao/x5NxSf5fz8hn4loSN...
#
# ...

# %%
if 'etag' in dt_jason.columns:
    dt_jason.drop('etag',axis=1,inplace=True)
else:
    print('no etag')

# %%
dt_jason
# Out:
#                       kind  id         snippet.channelId     snippet.title  \
# 0    youtube#videoCategory   1  UCBR8-60-B28hp2BmDPdntcQ  Film & Animation
# 1    youtube#videoCategory   2  UCBR8-60-B28hp2BmDPdntcQ  Autos & Vehicles
# 2    youtube#videoCategory  10  UCBR8-60-B28hp2BmDPdntcQ             Music
# 3    youtube#videoCategory  15  UCBR8-60-B28hp2BmDPdntcQ    Pets & Animals
# 4    youtube#videoCategory  17  UCBR8-60-B28hp2BmDPdntcQ            Sports
# ..                     ...  ..                       ...               ...
# 120  youtube#videoCategory  40  UCBR8-60-B28hp2BmDPdntcQ    Sci-Fi/Fantasy
# 121  youtube#videoCategory  41  UCBR8-60-B28hp2BmDPdntcQ          Thriller
# 122  youtube#videoCategory  42  UCBR8-60-B28hp2BmDPdntcQ            Shorts
# 123  youtube#videoCategory  43  UCBR8-60-B28hp2BmDPdntcQ             Shows
# 124  youtube#videoCategory  44  UCBR8-60-B28hp2BmDPdntcQ          Trailers
#
#      snippet.assignable
# 0                  True
# ...

# %%
dt_jason.drop(['kind','snippet.assignable'],axis=1,inplace=True)

# %%
dt_jason
# Out:
#      id         snippet.channelId     snippet.title
# 0     1  UCBR8-60-B28hp2BmDPdntcQ  Film & Animation
# 1     2  UCBR8-60-B28hp2BmDPdntcQ  Autos & Vehicles
# 2    10  UCBR8-60-B28hp2BmDPdntcQ             Music
# 3    15  UCBR8-60-B28hp2BmDPdntcQ    Pets & Animals
# 4    17  UCBR8-60-B28hp2BmDPdntcQ            Sports
# ..   ..                       ...               ...
# 120  40  UCBR8-60-B28hp2BmDPdntcQ    Sci-Fi/Fantasy
# 121  41  UCBR8-60-B28hp2BmDPdntcQ          Thriller
# 122  42  UCBR8-60-B28hp2BmDPdntcQ            Shorts
# 123  43  UCBR8-60-B28hp2BmDPdntcQ             Shows
# 124  44  UCBR8-60-B28hp2BmDPdntcQ          Trailers
#
# [125 rows x 3 columns]

# %%
vid_con["category_id"].nunique()
# Out:
# 16

# %%
vid_con1=vid_con.drop(['video_id','thumbnail_link','comments_disabled','ratings_disabled','video_error_or_removed','description'],axis=1)

# %%
vid_con1.rename(columns={'category_id': 'id'}, inplace=True)

# %%
vid_con1
# Out:
#      trending_date                                              title  \
# 0         17.14.11  Sing zu Ende! | Gesangseinlagen vom Feinsten |...
# 1         17.14.11  Kinder ferngesteuert im Kiosk! Erwachsene abzo...
# 2         17.14.11  The Trump Presidency: Last Week Tonight with J...
# 3         17.14.11                                Das Fermi-Paradoxon
# 4         17.14.11           18 SONGS mit Kelly MissesVlog (Sing-off)
# ...            ...                                                ...
# 2195      17.24.11  What Happens to You if You Upload Your Mind to...
# 2196      17.24.11  Kim Kardashian's Surrogate Didn't Know Whose B...
# 2197      17.24.11  Will Ferrell Left Speechless as Mark Wahlberg ...
# 2198      17.24.11               TRANSFORMING SUMMER MCKEEN INTO ME!!
# 2199      17.24.11  Emergence – How Stupid Things Become Smart Tog...
#
#                    channel_title  id              publish_time  \
# ...

# %%
vid_con1['id'].dtype
# Out:
# dtype('int64')

# %%
dt_jason['id'].dtypes
# Out:
# dtype('O')

# %%
dt_jason['id'] = dt_jason['id'].astype(int)

# %%
dt_jason
# Out:
#      id         snippet.channelId     snippet.title
# 0     1  UCBR8-60-B28hp2BmDPdntcQ  Film & Animation
# 1     2  UCBR8-60-B28hp2BmDPdntcQ  Autos & Vehicles
# 2    10  UCBR8-60-B28hp2BmDPdntcQ             Music
# 3    15  UCBR8-60-B28hp2BmDPdntcQ    Pets & Animals
# 4    17  UCBR8-60-B28hp2BmDPdntcQ            Sports
# ..   ..                       ...               ...
# 120  40  UCBR8-60-B28hp2BmDPdntcQ    Sci-Fi/Fantasy
# 121  41  UCBR8-60-B28hp2BmDPdntcQ          Thriller
# 122  42  UCBR8-60-B28hp2BmDPdntcQ            Shorts
# 123  43  UCBR8-60-B28hp2BmDPdntcQ             Shows
# 124  44  UCBR8-60-B28hp2BmDPdntcQ          Trailers
#
# [125 rows x 3 columns]

# %%
dt_jason.drop_duplicates(inplace=True)

# %%
dt_jason
# Out:
#     id         snippet.channelId          snippet.title
# 0    1  UCBR8-60-B28hp2BmDPdntcQ       Film & Animation
# 1    2  UCBR8-60-B28hp2BmDPdntcQ       Autos & Vehicles
# 2   10  UCBR8-60-B28hp2BmDPdntcQ                  Music
# 3   15  UCBR8-60-B28hp2BmDPdntcQ         Pets & Animals
# 4   17  UCBR8-60-B28hp2BmDPdntcQ                 Sports
# 5   18  UCBR8-60-B28hp2BmDPdntcQ           Short Movies
# 6   19  UCBR8-60-B28hp2BmDPdntcQ        Travel & Events
# 7   20  UCBR8-60-B28hp2BmDPdntcQ                 Gaming
# 8   21  UCBR8-60-B28hp2BmDPdntcQ          Videoblogging
# 9   22  UCBR8-60-B28hp2BmDPdntcQ         People & Blogs
# 10  23  UCBR8-60-B28hp2BmDPdntcQ                 Comedy
# 11  24  UCBR8-60-B28hp2BmDPdntcQ          Entertainment
# 12  25  UCBR8-60-B28hp2BmDPdntcQ        News & Politics
# 13  26  UCBR8-60-B28hp2BmDPdntcQ          Howto & Style
# 14  27  UCBR8-60-B28hp2BmDPdntcQ              Education
# 15  28  UCBR8-60-B28hp2BmDPdntcQ   Science & Technology
# ...

# %%
vid_con1
# Out:
#      trending_date                                              title  \
# 0         17.14.11  Sing zu Ende! | Gesangseinlagen vom Feinsten |...
# 1         17.14.11  Kinder ferngesteuert im Kiosk! Erwachsene abzo...
# 2         17.14.11  The Trump Presidency: Last Week Tonight with J...
# 3         17.14.11                                Das Fermi-Paradoxon
# 4         17.14.11           18 SONGS mit Kelly MissesVlog (Sing-off)
# ...            ...                                                ...
# 2195      17.24.11  What Happens to You if You Upload Your Mind to...
# 2196      17.24.11  Kim Kardashian's Surrogate Didn't Know Whose B...
# 2197      17.24.11  Will Ferrell Left Speechless as Mark Wahlberg ...
# 2198      17.24.11               TRANSFORMING SUMMER MCKEEN INTO ME!!
# 2199      17.24.11  Emergence – How Stupid Things Become Smart Tog...
#
#                    channel_title  id              publish_time  \
# ...

# %%
vid_con1.drop_duplicates(inplace=True)

# %%
vid_con1.isna().sum()
# Out:
# trending_date    0
# title            0
# channel_title    0
# id               0
# publish_time     0
# tags             0
# views            0
# likes            0
# dislikes         0
# comment_count    0
# dtype: int64

# %%
main = pd.merge(vid_con1,dt_jason,how='inner',on = "id")

# %%
main
# Out:
#      trending_date                                              title  \
# 0         17.14.11  Sing zu Ende! | Gesangseinlagen vom Feinsten |...
# 1         17.14.11  Kinder ferngesteuert im Kiosk! Erwachsene abzo...
# 2         17.14.11  The Trump Presidency: Last Week Tonight with J...
# 3         17.14.11                                Das Fermi-Paradoxon
# 4         17.14.11           18 SONGS mit Kelly MissesVlog (Sing-off)
# ...            ...                                                ...
# 8030      17.24.11  What Happens to You if You Upload Your Mind to...
# 8031      17.24.11  Kim Kardashian's Surrogate Didn't Know Whose B...
# 8032      17.24.11  Will Ferrell Left Speechless as Mark Wahlberg ...
# 8033      17.24.11               TRANSFORMING SUMMER MCKEEN INTO ME!!
# 8034      17.24.11  Emergence – How Stupid Things Become Smart Tog...
#
#                    channel_title  id              publish_time  \
# ...

# %%
## Description

# %%
main.isna().sum()
# Out:
# trending_date        0
# title                0
# channel_title        0
# id                   0
# publish_time         0
# tags                 0
# views                0
# likes                0
# dislikes             0
# comment_count        0
# snippet.channelId    0
# snippet.title        0
# dtype: int64

# %%
main.describe()
# Out:
#                 id         views         likes       dislikes  comment_count
# count  8035.000000  8.035000e+03  8.035000e+03    8035.000000    8035.000000
# mean     20.343995  7.109380e+05  2.739682e+04    1103.305538    2739.977100
# std       7.080630  2.803117e+06  1.130954e+05    6659.317060    9406.567951
# min       1.000000  6.870000e+02  0.000000e+00       0.000000       0.000000
# 25%      17.000000  3.396950e+04  5.280000e+02      29.000000      91.000000
# 50%      23.000000  1.396400e+05  3.398000e+03     133.000000     465.000000
# 75%      24.000000  4.773935e+05  1.513850e+04     522.000000    1712.000000
# max      43.000000  8.060586e+07  2.173715e+06  244229.000000  127481.000000

# %%
main.describe(include='all')
# Out:
#        trending_date                                      title  \
# count           8035                                       8035
# unique            11                                       4719
# top         17.14.11  Luis Fonsi, Demi Lovato - Échame La Culpa
# freq             752                                         19
# mean             NaN                                        NaN
# std              NaN                                        NaN
# min              NaN                                        NaN
# 25%              NaN                                        NaN
# 50%              NaN                                        NaN
# 75%              NaN                                        NaN
# max              NaN                                        NaN
#
#                                channel_title           id  \
# count                                   8035  8035.000000
# unique                                  2739          NaN
# ...

# %%
main.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8035 entries, 0 to 8034
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   trending_date      8035 non-null   object
#  1   title              8035 non-null   object
#  2   channel_title      8035 non-null   object
#  3   id                 8035 non-null   int64
#  4   publish_time       8035 non-null   object
#  5   tags               8035 non-null   object
#  6   views              8035 non-null   int64
#  7   likes              8035 non-null   int64
#  8   dislikes           8035 non-null   int64
#  9   comment_count      8035 non-null   int64
#  10  snippet.channelId  8035 non-null   object
#  11  snippet.title      8035 non-null   object
# dtypes: int64(5), object(7)
# memory usage: 753.4+ KB

# %%
main.dtypes
# Out:
# trending_date        object
# title                object
# channel_title        object
# id                    int64
# publish_time         object
# tags                 object
# views                 int64
# likes                 int64
# dislikes              int64
# comment_count         int64
# snippet.channelId    object
# snippet.title        object
# dtype: object

# %%
main.count()
# Out:
# trending_date        8035
# title                8035
# channel_title        8035
# id                   8035
# publish_time         8035
# tags                 8035
# views                8035
# likes                8035
# dislikes             8035
# comment_count        8035
# snippet.channelId    8035
# snippet.title        8035
# dtype: int64
